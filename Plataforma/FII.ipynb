# %%
url = "http://vps-40d69db1.vps.ovh.ca:23005/api/FundoImobiliarios"

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)

# %%
df.head()
# Out:
#     ticker                                nome                  segmento  \
# 0  ABCP11                Grand Plaza Shopping           Shopping/Varejo
# 1  AFCR11   AF Invest Recebíveis Imobiliários   Recebíveis Imobiliários
# 2  AFHI11                       AF Invest CRI   Recebíveis Imobiliários
# 3  AFOF11                         Alianza FOF           Fundo de Fundos
# 4  AIEC11     Autonomy Edifícios Corporativos          Lajes Comerciais
#
#          administrador                                          descricao  \
# 0           RIO BRAVO   O FII atualmente é proprietário do edifício co...
# 1  CM CAPITAL MARKETS   O Fundo tem como objetivo a aquisição de ativo...
# 2         BTG PACTUAL   O objetivo do Fundo é aplicar recursos em empr...
# 3           BRL TRUST                                            SEGMENTO
# 4                 MAF   O Autonomy Edifícios Corporativos Fundo de Inv...
#
#    percentual12  percentual6  mediaNegocio1  mediaNegocio3  mediaNegocio4  \
# ...

# %%
dfSort= df.sort_values(by='variacao12m', ascending=True)

# %%
dfSort.head(20)
# Out:
#        ticker                                         nome  \
# 245  RCRI11B                       RB Capital Rendimentos
# 26    BLMO11                     BlueMacaw Office Fund II
# 138   HUSI11                                         HUSI
# 45    BTWR11                                      BTowers
# 195   ORPD11       Ouro Verde Desenvolvimento Imobiliário
# 7    ANCR11B                                     Ancar IC
# 275   SOLR11                                     Solarium
# 74    EQIN11   NCH EQI High Yield Recebíveis Imobiliários
# 166  LOFT11B                         Loft I (Cota Sênior)
# 110   HBCR11                             HBC Renda Urbana
# 173   MCCI11         Mauá Capital Recebíveis Imobiliários
# 56    CPTS11                      Capitânia Securities II
# 273   SNCI11                              Suno Recebíveis
# 285   THRA11                       Cyrela Thera Corporate
# 264  SAIC11B                                SIA Corporate
# ...

# %%
dfMelhores = dfSort[dfSort['mediaPercentualAluguel6']>1]

# %%
dfMelhores.head(10)
# Out:
#       ticker                                       nome  \
# 275  SOLR11                                   Solarium
# 56   CPTS11                    Capitânia Securities II
# 227  RBHY11   Rio Bravo Crédito Imobiliário High Yield
# 219  RBBV11           JHSF Rio Bravo Fazenda Boa Vista
# 247  RECR11                REC Recebíveis Imobiliários
# 59   CVBI11                                    VBI CRI
# 157  KNHY11                       Kinea High Yield CRI
# 13   BARI11                        Barigui Rendimentos
# 20   BCRI11           Banestes Recebíveis Imobiliários
# 164  LFTT11                                    Loft II
#
#                       segmento             administrador  \
# 275                   Híbrido      GENIAL INVESTIMENTOS
# 56    Recebíveis Imobiliários               BTG PACTUAL
# 227   Recebíveis Imobiliários                 BRL TRUST
# 219              Incorporação   CAIXA ECONOMICA FEDERAL
# 247   Recebíveis Imobiliários                 BRL TRUST
# ...
