# %%
url = "http://vps-40d69db1.vps.ovh.ca:21546/api/CotacaoIntradayFoxbits/obtemListaFoxbit?ticker=ETH"

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)

# %%
df.plot(x="dataHora", y=["valor"], 
             figsize=(18,5), legend=None)
plt.show()

# %%
df.tail(50)
# Out:
#     ticker       valor    diaNum  \
# 456    ETH  22932.8600  20211216
# 457    ETH  23078.9300  20211216
# 458    ETH  22865.9400  20211216
# 459    ETH  22977.1492  20211216
# 460    ETH  23017.2135  20211216
# 461    ETH  22864.3194  20211216
# 462    ETH  22726.6100  20211216
# 463    ETH  22793.5400  20211216
# 464    ETH  22958.9100  20211216
# 465    ETH  22927.3798  20211216
# 466    ETH  22725.1000  20211216
# 467    ETH  22660.4000  20211216
# 468    ETH  22800.0000  20211216
# 469    ETH  22860.1200  20211217
# 470    ETH  22660.0100  20211217
# 471    ETH  22998.0596  20211217
# 472    ETH  22980.6995  20211217
# 473    ETH  22735.1200  20211217
# 474    ETH  22735.1200  20211217
# 475    ETH  22976.8698  20211217
# 476    ETH  22971.5699  20211217
# 477    ETH  22971.5699  20211217
# 478    ETH  22971.5699  20211217
# 479    ETH  22971.5699  20211217
# 480    ETH  22971.5699  20211217
# 481    ETH  22971.5699  20211217
# 482    ETH  22971.5699  20211217
# ...
