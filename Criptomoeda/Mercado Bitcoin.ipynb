# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
url = "http://vps-40d69db1.vps.ovh.ca:22001/api/CotacaoIntradayMercadoBitcoins/fechamentosPorDiaNum?diaNum=20220211"

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)

# %%
df2 = df.set_index('ticker')

# %%
df2.head()
# Out:
#             valor                  dataHora
# ticker
# AAVE    880.30799  2022-02-11T23:59:26.000Z
# ACMFT    23.98900  2022-02-11T23:59:26.000Z
# ADA       5.79571  2022-02-11T23:59:27.000Z
# ALCX    895.00000  2022-02-11T23:59:36.000Z
# ALGO      4.99988  2022-02-11T23:59:36.000Z

# %%
url1mes = "http://vps-40d69db1.vps.ovh.ca:22001/api/CotacaoIntradayMercadoBitcoins/fechamentosPorDiaNum?diaNum=20220111"

# %%
r = requests.get(url1mes)
j = r.json()
df1mes = pd.DataFrame.from_dict(j)

# %%
df1mes = df1mes.set_index('ticker')

# %%
df1mes.head()
# Out:
#              valor                  dataHora
# ticker
# AAVE    1221.88987  2022-01-11T23:52:06.000Z
# ACMFT     27.49489  2022-01-11T23:52:07.000Z
# ADA        6.74975  2022-01-11T23:52:09.000Z
# ALGO       8.24995  2022-01-11T23:52:11.000Z
# AMFT       7.63989  2022-01-11T23:52:13.000Z

# %%
dfmerge = pd.merge(df1mes,df2,how='inner' , left_index=True, right_index=True, suffixes=('_1', '_0'))

# %%
dfmerge.head()
# Out:
#            valor_1                dataHora_1    valor_0  \
# ticker
# AAVE    1221.88987  2022-01-11T23:52:06.000Z  880.30799
# ACMFT     27.49489  2022-01-11T23:52:07.000Z   23.98900
# ADA        6.74975  2022-01-11T23:52:09.000Z    5.79571
# ALGO       8.24995  2022-01-11T23:52:11.000Z    4.99988
# AMFT       7.63989  2022-01-11T23:52:13.000Z    6.01000
#
#                       dataHora_0
# ticker
# AAVE    2022-02-11T23:59:26.000Z
# ACMFT   2022-02-11T23:59:26.000Z
# ADA     2022-02-11T23:59:27.000Z
# ALGO    2022-02-11T23:59:36.000Z
# AMFT    2022-02-11T23:50:43.000Z

# %%
dfmerge['lucro'] = dfmerge['valor_0'] - dfmerge['valor_1']

# %%
dfmerge.sort_values(by='lucro', ascending=False)
# Out:
#                   valor_1                dataHora_1        valor_0  \
# ticker
# PSGFT           83.435840  2022-01-11T23:53:37.000Z      88.560050
# MBSANTOS01      50.000000  2022-01-11T23:53:29.000Z      50.000000
# SHIB             0.000159  2022-01-11T23:53:43.000Z       0.000155
# ARGFT            8.880000  2022-01-11T23:52:15.000Z       8.840010
# DOGE             0.861920  2022-01-11T23:52:50.000Z       0.773850
# XRP              4.340020  2022-01-11T23:54:11.000Z       4.110150
# DAI              5.608520  2022-01-11T23:52:43.000Z       5.289110
# USDC             5.620520  2022-01-11T23:53:55.000Z       5.296160
# GALOFT           4.500000  2022-01-11T23:53:05.000Z       3.739980
# SCCPFT           4.650000  2022-01-11T23:53:41.000Z       3.870050
# MANA            16.499820  2022-01-11T23:53:25.000Z      15.718490
# ADA              6.749750  2022-01-11T23:52:09.000Z       5.795710
# GRT              3.219260  2022-01-11T23:53:07.000Z       2.236390
# ...
