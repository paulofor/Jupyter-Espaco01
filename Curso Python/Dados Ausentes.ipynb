# %%
import numpy as np
from datetime import datetime
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "http://vps-40d69db1.vps.ovh.ca:21046/api/ExecucaoSimulacaos/melhorValidacaoPeriodoFlat?idPeriodo=9"
r = requests.get('http://vps-40d69db1.vps.ovh.ca:21046/api/ExecucaoSimulacaos/melhorValidacaoPeriodoFlat?idPeriodo=9')
j = r.json()
df = pd.DataFrame.from_dict(j)

# %%
dfTicker = df.groupby(['ticker','saldoValidacao']).size().reset_index(name ='qtde')
dfTicker2 = dfTicker.pivot_table('qtde','ticker','saldoValidacao')

# %%
dfTicker2.head()
# Out:
# saldoValidacao  -3.0  -2.0    -1.0    0.0    1.0   2.0
# ticker
# AERI3            NaN   NaN     NaN  227.0   22.0  50.0
# ALPA4            NaN   NaN     NaN  695.0    NaN   NaN
# ALSO3            NaN   NaN     NaN   21.0  120.0   NaN
# AMAR3            NaN   NaN   261.0  658.0  155.0   NaN
# ANIM3            NaN   NaN  1182.0  364.0   68.0   NaN

# %% [markdown]
# # Inicio da Lição

# %% [markdown]
# ## Máscara de Nulos

# %%
mask = dfTicker2.isnull()
mask.head()
# Out:
# saldoValidacao  -3.0  -2.0   -1.0    0.0    1.0    2.0
# ticker
# AERI3           True  True   True  False  False  False
# ALPA4           True  True   True  False   True   True
# ALSO3           True  True   True  False  False   True
# AMAR3           True  True  False  False  False   True
# ANIM3           True  True  False  False  False   True

# %% [markdown]
# ## Retirando linhas com nulos

# %%
dfTicker2.dropna().head()
# Out:
# Empty DataFrame
# Columns: [-3.0, -2.0, -1.0, 0.0, 1.0, 2.0]
# Index: []

# %% [markdown]
# ## Preencher com outros valores

# %%
dfTicker2.fillna(0, inplace=True)

# %%
dfTicker2.head()
# Out:
# saldoValidacao  -3.0  -2.0    -1.0    0.0    1.0   2.0
# ticker
# AERI3            0.0   0.0     0.0  227.0   22.0  50.0
# ALPA4            0.0   0.0     0.0  695.0    0.0   0.0
# ALSO3            0.0   0.0     0.0   21.0  120.0   0.0
# AMAR3            0.0   0.0   261.0  658.0  155.0   0.0
# ANIM3            0.0   0.0  1182.0  364.0   68.0   0.0

# %% [markdown]
# ## Outros exemplos

# %%
df = pd.DataFrame({'A' : [1,1,2,3,4] , 'B' : [3,6,3,8,9] , 'C' : ['a' , 'b' , 'c' , 'd' , 'e'] })
df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
df.replace(1,132)
# Out:
#      A  B  C
# 0  132  3  a
# 1  132  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
df.replace([1,3], [100,300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e
