# %%
url = "http://vps-40d69db1.vps.ovh.ca:21046/api/CotacaoIntradayAcaoResultadoValors/obtemListaTickerRegra?ticker=ABEV3&idRegra=1"

# %%
import requests
import pandas as pd

r = requests.get(url)

j = r.json()

dfABEV3 = pd.DataFrame.from_dict(j)

# %%
dfABEV3.head()
# Out:
#   ticker    diaNum      hora  resultado       diaHoraNumTicker  dias  \
# 0  ABEV3  20210104  10:40:00          0  2021010410:40:00ABEV3    40
# 1  ABEV3  20210104  11:00:00          0  2021010411:00:00ABEV3    40
# 2  ABEV3  20210104  11:30:00          0  2021010411:30:00ABEV3    40
# 3  ABEV3  20210104  12:00:00          0  2021010412:00:00ABEV3    40
# 4  ABEV3  20210104  12:30:00          0  2021010412:30:00ABEV3    40
#
#    regraProjecaoId          dataHoraInsercao  valorSaida  valorEntrada  \
# 0                1  2021-11-25T17:39:12.000Z         0.0         15.65
# 1                1  2021-11-25T17:39:12.000Z         0.0         15.65
# 2                1  2021-11-25T17:39:12.000Z         0.0         15.65
# 3                1  2021-11-25T17:39:12.000Z         0.0         15.70
# 4                1  2021-11-25T17:39:12.000Z         0.0         15.67
#
#    diaNumSaida
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
import matplotlib.pyplot as plt

# %%
dfABEV3.plot(x="diaHoraNumTicker", y=["valorEntrada","resultado"])
plt.show()

# %%
dfABEV3.tail(100)
# Out:
#      ticker    diaNum      hora  resultado       diaHoraNumTicker  dias  \
# 3034  ABEV3  20211027  12:30:00          1  2021102712:30:00ABEV3     5
# 3035  ABEV3  20211027  13:00:00          1  2021102713:00:00ABEV3     5
# 3036  ABEV3  20211027  13:30:00          1  2021102713:30:00ABEV3     5
# 3037  ABEV3  20211027  14:00:00          1  2021102714:00:00ABEV3     5
# 3038  ABEV3  20211027  14:30:00          1  2021102714:30:00ABEV3     5
# ...     ...       ...       ...        ...                    ...   ...
# 3129  ABEV3  20211105  15:00:00          0  2021110515:00:00ABEV3    40
# 3130  ABEV3  20211105  15:30:00          0  2021110515:30:00ABEV3    40
# 3131  ABEV3  20211105  16:00:00          0  2021110516:00:00ABEV3    40
# 3132  ABEV3  20211105  16:30:00          0  2021110516:30:00ABEV3    40
# 3133  ABEV3  20211105  17:30:00          0  2021110517:30:00ABEV3    40
#
#       regraProjecaoId          dataHoraInsercao  valorSaida  valorEntrada  \
# 3034                1  2021-11-25T17:39:22.000Z      17.779         15.46
# 3035                1  2021-11-25T17:39:22.000Z      17.790         15.47
# 3036                1  2021-11-25T17:39:22.000Z      17.653         15.35
# 3037                1  2021-11-25T17:39:22.000Z      17.687         15.38
# 3038                1  2021-11-25T17:39:22.000Z      17.653         15.35
# ...               ...                       ...         ...           ...
# 3129                1  2021-11-25T17:39:22.000Z       0.000         17.94
# 3130                1  2021-11-25T17:39:22.000Z       0.000         17.99
# 3131                1  2021-11-25T17:39:22.000Z       0.000         17.96
# 3132                1  2021-11-25T17:39:22.000Z       0.000         17.90
# 3133                1  2021-11-25T17:39:22.000Z       0.000         17.90
#
#       diaNumSaida
# 3034     20211103
# 3035     20211103
# 3036     20211103
# 3037     20211103
# 3038     20211103
# ...           ...
# 3129            0
# 3130            0
# 3131            0
# 3132            0
# 3133            0
#
# [100 rows x 11 columns]
