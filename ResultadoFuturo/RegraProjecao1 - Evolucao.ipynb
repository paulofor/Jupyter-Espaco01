# %% [markdown]
# # Inicializações

# %%
url = "http://vps-40d69db1.vps.ovh.ca:21446/api/CotacaoIntradayAcaoResultadoValors/obtemPorRegraData?idRegra=1&diaNum=20210101"

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %% [markdown]
# # Execuções no tempo

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)
dfTicker = df.groupby(['ticker']).agg('qtde').sum().reset_index(name ='total')

now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

print('Data : ' , dt_string)
print('Total: ' , df.agg('qtde').sum())
print('Ticker: ' , len(dfTicker))


dfTicker.plot.bar(x='ticker', y='total', rot=0, figsize=(18,5), legend=None)
plt.show()

print(dfTicker)
# Out:
# Data :  08/01/2022 12:32:40
# Total:  211268
# Ticker:  73
#    ticker  total
# 0   ABEV3   3034
# 1   AZUL4   3414
# 2   B3SA3   3000
# 3   BBAS3   2974
# 4   BBDC3   2793
# ..    ...    ...
# 68  VALE3   2744
# 69  VVAR3   1990
# 70  WEGE3   2918
# 71  WIZS3   3286
# 72  YDUQ3   3256
#
# [73 rows x 2 columns]

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)
dfTicker = df.groupby(['ticker']).agg('qtde').sum().reset_index(name ='total')

now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

print('Data : ' , dt_string)
print('Total: ' , df.agg('qtde').sum())
print('Ticker: ' , len(dfTicker))


dfTicker.plot.bar(x='ticker', y='total', rot=0, figsize=(18,5), legend=None)
plt.show()

print(dfTicker)
# Out:
# Data :  06/01/2022 10:50:57
# Total:  209938
# Ticker:  73
#    ticker  total
# 0   ABEV3   2947
# 1   AZUL4   3309
# 2   B3SA3   2991
# 3   BBAS3   2959
# 4   BBDC3   2778
# ..    ...    ...
# 68  VALE3   2744
# 69  VVAR3   1990
# 70  WEGE3   2898
# 71  WIZS3   3244
# 72  YDUQ3   3224
#
# [73 rows x 2 columns]

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)
dfTicker = df.groupby(['ticker']).agg('qtde').sum().reset_index(name ='total')

now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

print('Data : ' , dt_string)
print('Total: ' , df.agg('qtde').sum())
print('Ticker: ' , len(dfTicker))


dfTicker.plot.bar(x='ticker', y='total', rot=0, figsize=(18,5), legend=None)
plt.show()

print(dfTicker)
# Out:
# Data :  04/01/2022 15:43:29
# Total:  207938
# Ticker:  73
#    ticker  total
# 0   ABEV3   2910
# 1   AZUL4   3266
# 2   B3SA3   2936
# 3   BBAS3   2921
# 4   BBDC3   2748
# ..    ...    ...
# 68  VALE3   2744
# 69  VVAR3   1990
# 70  WEGE3   2705
# 71  WIZS3   3116
# 72  YDUQ3   3096
#
# [73 rows x 2 columns]

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)
dfTicker = df.groupby(['ticker']).agg('qtde').sum().reset_index(name ='total')

now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

print('Data : ' , dt_string)
print('Total: ' , df.agg('qtde').sum())
print('Ticker: ' , len(dfTicker))


dfTicker.plot.bar(x='ticker', y='total', rot=0, figsize=(18,5), legend=None)
plt.show()

print(dfTicker)
# Out:
# Data :  01/01/2022 15:25:37
# Total:  142057
# Ticker:  50
#     ticker  total
# 0    ABEV3   2864
# 1    AZUL4   3266
# 2    B3SA3   2878
# 3    BBAS3   2920
# 4    BBDC3   2493
# 5    BBDC4   2805
# 6    BBSE3   2490
# 7   BPAC11   2845
# 8    BRDT3   2260
# 9    BRFS3   3267
# 10   BRML3   2777
# 11   CCRO3   2790
# 12   CIEL3   3019
# 13   CMIG4   2710
# 14   COGN3   3104
# 15   CPLE6   2490
# 16   CSAN3   2900
# 17   CSNA3   2799
# 18   CYRE3   2814
# 19   ELET3   2988
# 20   EMBR3   3303
# 21   ENEV3   2828
# 22   EQTL3   2490
# 23   GGBR4   2903
# 24   GOAU4   2767
# 25   GOLL4   3160
# 26   HAPV3   2798
# 27   ITUB4   3000
# 28   JBSS3   2628
# 29  KLBN11   2723
# 30   LREN3   3109
# 31   LWSA3   3232
# 32   MGLU3   3133
# 33   MRFG3   2875
# 34   MULT3   2864
# 35   NTCO3   3086
# 36   PETR3   3127
# 37   PETR4   2939
# 38   PRIO3   3020
# 39   RADL3   2620
# 40   RAIL3   2494
# 41   RENT3   2781
# 42  SULA11   2569
# 43   SUZB3   2921
# 44   TOTS3   2985
# 45   UGPA3   2705
# 46   USIM5   3081
# 47   VALE3   2744
# 48   VVAR3   1990
# 49   WEGE3   2703

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)
dfTicker = df.groupby(['ticker']).agg('qtde').sum().reset_index(name ='total')

now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

print('Data : ' , dt_string)
print('Total: ' , df.agg('qtde').sum())
print('Ticker: ' , len(dfTicker))


dfTicker.plot.bar(x='ticker', y='total', rot=0, figsize=(18,5), legend=None)
plt.show()

print(dfTicker)
# Out:
# Data :  30/12/2021 11:34:40
# Total:  73619
# Ticker:  27
#     ticker  total
# 0    ABEV3   2807
# 1    B3SA3   2818
# 2    BBAS3   2901
# 3    BBDC4   2745
# 4    BBSE3   2490
# 5   BPAC11   2825
# 6    BRDT3   2260
# 7    BRFS3   3267
# 8    BRML3   2765
# 9    CCRO3   2790
# 10   CIEL3    360
# 11   CSAN3   2858
# 12   CSNA3   2777
# 13   GGBR4   2882
# 14   ITUB4   2945
# 15   JBSS3   2581
# 16   LREN3   3109
# 17   MGLU3   3014
# 18   NTCO3   3072
# 19   PETR3   3075
# 20   PETR4   2879
# 21   PRIO3   3020
# 22   SUZB3   2921
# 23   USIM5   3080
# 24   VALE3   2713
# 25   VVAR3   1990
# 26   WEGE3   2675

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)
dfTicker = df.groupby(['ticker']).agg('qtde').sum().reset_index(name ='total')

now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

print('Data : ' , dt_string)
print('Total: ' , df.agg('qtde').sum())
print('Ticker: ' , len(dfTicker))


dfTicker.plot.bar(x='ticker', y='total', rot=0, figsize=(18,5), legend=None)
plt.show()

print(dfTicker)
# Out:
# Data :  21/12/2021 12:39:30
# Total:  55034
# Ticker:  20
#     ticker  total
# 0    ABEV3   2807
# 1    B3SA3   2780
# 2    BBAS3   2863
# 3    BBDC4   2700
# 4   BPAC11   2804
# 5    BRDT3   2260
# 6    BRML3   2765
# 7    CSAN3   2813
# 8    CSNA3   2777
# 9    GGBR4   2879
# 10   ITUB4   2900
# 11   JBSS3   2536
# 12   LREN3   2973
# 13   MGLU3   3014
# 14   PETR3   3030
# 15   PETR4   2834
# 16   SUZB3   2921
# 17   VALE3   2713
# 18   VVAR3   1990
# 19   WEGE3   2675
