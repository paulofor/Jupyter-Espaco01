# %%
url = "http://vps-40d69db1.vps.ovh.ca:22001/api/TipoAplicacaos/obtemComSaldoPorPeriodo?dataRefNum=202112"

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
r = requests.get(url)
j = r.json()
df = pd.DataFrame.from_dict(j)

# %%
df.head()
# Out:
#    tipoAplicacaoId               nome    total  percentualTotal
# 0                3  Fundo Imobiliário  8971.40           27.384
# 1                5     Tesouro Direto  8636.38           26.361
# 2                2              Ações  5677.66           17.330
# 3                4                CDB  3122.83            9.532
# 4                1           Poupança  2900.00            8.852

# %%
df.plot(kind='pie', y = 'total', autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=df['nome'], legend = False, fontsize=14, figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='total'>
